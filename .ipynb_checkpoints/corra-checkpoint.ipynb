# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import ccf, adfuller, grangercausalitytests
from scipy import stats
import seaborn as sns
from matplotlib.animation import FuncAnimation

# 设置随机种子以确保结果可重现
np.random.seed(42)

# 生成示例数据
t = np.linspace(0, 100, 1000)
A = np.sin(0.1 * t)# + 0.1 * np.random.randn(1000)
B = np.sin(0.1 * (t - 10))# + 0.1 * np.random.randn(1000)  # B滞后A 10个单位

# 创建DataFrame
df = pd.DataFrame({'A': A, 'B': B}, index=pd.date_range(start='2023-01-01', periods=1000, freq='H'))

# 1. 单位根检验（ADF检验）
def adf_test(series):
    result = adfuller(series)
    print(f'ADF Test for {series.name}:')
    print(f'ADF Statistic: {result[0]}')
    print(f'p-value: {result[1]}')
    print('Critical Values:')
    for key, value in result[4].items():
        print(f'\t{key}: {value}')
    print('Conclusion:')
    print('\tThe series is stationary.' if result[1] < 0.05 else '\tThe series is non-stationary.')
    print()

print("Performing Augmented Dickey-Fuller (ADF) Test:")
adf_test(df['A'])
adf_test(df['B'])

# 2. 交叉相关分析
lag_range = 100
ccf_result = ccf(df['A'], df['B'], adjusted=False)
lags = np.arange(-lag_range, lag_range + 1)
ccf_values = ccf_result[len(ccf_result)//2-lag_range:len(ccf_result)//2+lag_range+1]

max_lag = lags[np.argmax(np.abs(ccf_values))]
max_corr = ccf_values[np.argmax(np.abs(ccf_values))]

print("\nCross-Correlation Analysis:")
print(f"Maximum correlation occurs at lag {max_lag}")
print(f"Maximum correlation value: {max_corr:.4f}")

# 3. Granger因果检验
print("\nPerforming Granger Causality Test:")
if max_lag >= 0:
    granger_result = grangercausalitytests(df[['A', 'B']], maxlag=abs(max_lag), verbose=False)
    print("Testing if A Granger-causes B")
else:
    granger_result = grangercausalitytests(df[['B', 'A']], maxlag=abs(max_lag), verbose=False)
    print("Testing if B Granger-causes A")

# 提取并打印Granger因果检验的结果
print("Granger Causality Test Results:")
for lag, result in granger_result.items():
    f_test = result[0]['ssr_ftest']
    print(f"Lag {lag}:")
    print(f"  F-statistic: {f_test[0]:.4f}")
    print(f"  p-value: {f_test[1]:.4f}")
    if max_lag >= 0:
        print(f"  Conclusion: {'A Granger-causes B' if f_test[1] < 0.05 else 'A does not Granger-cause B'}")
    else:
        print(f"  Conclusion: {'B Granger-causes A' if f_test[1] < 0.05 else 'B does not Granger-cause A'}")
    print()

# 4. 相关系数
correlation = df['A'].corr(df['B'])
print(f"\nPearson Correlation Coefficient: {correlation:.4f}")

# 5. 画图展示结果

# 设置Seaborn样式
sns.set_theme(style="darkgrid")

# 交叉相关图
plt.figure(figsize=(12, 6))
plt.plot(lags, ccf_values)
plt.axvline(x=0, color='r', linestyle='--')
plt.axhline(y=0, color='r', linestyle='--')
plt.title('Cross-Correlation between A and B', fontsize=16)
plt.xlabel('Lag', fontsize=12)
plt.ylabel('Correlation', fontsize=12)
plt.annotate(f'Max correlation at lag {max_lag}\nCorrelation: {max_corr:.2f}', 
             xy=(max_lag, max_corr), xytext=(max_lag + 5, max_corr),
             arrowprops=dict(arrowstyle="->", color='red'))
plt.tight_layout()
plt.show()

# 时间序列图
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['A'], label='A', color='#1f77b4')
plt.plot(df.index, df['B'], label='B', color='#d62728')
plt.title('Time Series A and B', fontsize=16)
plt.xlabel('Time', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.legend(fontsize=10)
plt.tight_layout()
plt.show()

# 动态可视化函数
def create_animation():
    fig, ax = plt.subplots(figsize=(12, 6))

    def animate(i):
        ax.clear()
        shift = i - 50  # 从-50到50的偏移
        df_shifted = df.copy()
        df_shifted['A_shifted'] = df_shifted['A'].shift(shift)
        
        ax.plot(df_shifted.index, df_shifted['B'], label='B', color='#1f77b4')
        ax.plot(df_shifted.index, df_shifted['A_shifted'], label=f'A (shifted by {shift})', color='#d62728', alpha=0.7)
        
        ax.set_title(f'Time Series A and B (A shifted by {shift})', fontsize=16)
        ax.set_xlabel('Time', fontsize=12)
        ax.set_ylabel('Value', fontsize=12)
        ax.legend(fontsize=10)
        
        # 添加相关系数注释
        corr = df_shifted['A_shifted'].corr(df_shifted['B'])
        ax.annotate(f'Correlation: {corr:.2f}', xy=(0.05, 0.95), xycoords='axes fraction',
                    bbox=dict(boxstyle="round,pad=0.3", fc="white", ec="gray", alpha=0.8),
                    fontsize=10)

    anim = FuncAnimation(fig, animate, frames=101, interval=100, blit=False)
    plt.tight_layout()
    plt.show()

# 创建并显示动画
create_animation()
# Out:
# /var/folders/08/51ch_vwn57lgdw3v47gn9rjh0000gn/T/ipykernel_3187/1688836439.py:18: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   df = pd.DataFrame({'A': A, 'B': B}, index=pd.date_range(start='2023-01-01', periods=1000, freq='H'))
# /Users/mmcao/anaconda3/envs/tinyrag/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:1545: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# Performing Augmented Dickey-Fuller (ADF) Test:
# ADF Test for A:
# ADF Statistic: -4848834135330.625
# p-value: 0.0
# Critical Values:
# 	1%: -3.4369259442540416
# 	5%: -2.8644432969122833
# 	10%: -2.5683158550174094
# Conclusion:
# 	The series is stationary.
#
# ADF Test for B:
# ADF Statistic: -19759695570345.848
# p-value: 0.0
# Critical Values:
# 	1%: -3.4369525024039884
# 	5%: -2.8644550095200705
# 	10%: -2.568322093455802
# Conclusion:
# 	The series is stationary.
#
#
# Cross-Correlation Analysis:
# Maximum correlation occurs at lag -11
# Maximum correlation value: 0.3777
#
# Performing Granger Causality Test:
# ---------------------------------------------------------------------------
# InfeasibleTestError                       Traceback (most recent call last)
# Cell In[9], line 56
#      54     print("Testing if A Granger-causes B")
#      55 else:
# ---> 56     granger_result = grangercausalitytests(df[['B', 'A']], maxlag=abs(max_lag), verbose=False)
#      57     print("Testing if B Granger-causes A")
#      59 # 提取并打印Granger因果检验的结果
#
# File ~/anaconda3/envs/tinyrag/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:1622, in grangercausalitytests(x, maxlag, addconst, verbose)
#    1614     tss = res2djoint.uncentered_tss
#    1615 if (
#    1616     tss == 0
#    1617     or res2djoint.ssr == 0
#    (...)
#    1620     or res2djoint.params.shape[0] != dtajoint.shape[1]
#    1621 ):
# -> 1622     raise InfeasibleTestError(
#    1623         "The Granger causality test statistic cannot be compute "
#    1624         "because the VAR has a perfect fit of the data."
#    1625     )
#    1626 fgc1 = (
#    1627     (res2down.ssr - res2djoint.ssr)
#    1628     / res2djoint.ssr
#    1629     / mxlg
#    1630     * res2djoint.df_resid
#    1631 )
#    1632 if verbose:
#
# InfeasibleTestError: The Granger causality test statistic cannot be compute because the VAR has a perfect fit of the data.

# %%
# 修改后的时间序列图
fig, ax1 = plt.subplots(figsize=(12, 6))

color_A = '#1f77b4'
color_B = '#d62728'

ax1.set_xlabel('Time', fontsize=12)
ax1.set_ylabel('A', color=color_A, fontsize=12)
ax1.plot(df.index, df['A'], color=color_A, label='A')
ax1.tick_params(axis='y', labelcolor=color_A)

ax2 = ax1.twinx()  # 创建共享x轴的第二个y轴
ax2.set_ylabel('B', color=color_B, fontsize=12)
ax2.plot(df.index, df['B'], color=color_B, label='B')
ax2.tick_params(axis='y', labelcolor=color_B)

plt.title('Time Series A and B', fontsize=16)
fig.tight_layout()
lines_A, labels_A = ax1.get_legend_handles_labels()
lines_B, labels_B = ax2.get_legend_handles_labels()
ax1.legend(lines_A + lines_B, labels_A + labels_B, loc='upper left', fontsize=10)
plt.show()

# 修改后的动态可视化函数
def create_animation():
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

    def animate(i):
        ax1.clear()
        ax2.clear()
        shift = i - 50  # 从-50到50的偏移
        df_shifted = df.copy()
        df_shifted['A_shifted'] = df_shifted['A'].shift(shift)
        
        # 左侧图：A的原始数据和shifted数据
        ax1.plot(df_shifted.index, df_shifted['A'], label='A (original)', color='#1f77b4')
        ax1.plot(df_shifted.index, df_shifted['A_shifted'], label=f'A (shifted by {shift})', color='#d62728', alpha=0.7)
        ax1.set_title(f'Time Series A (shifted by {shift})', fontsize=16)
        ax1.set_xlabel('Time', fontsize=12)
        ax1.set_ylabel('A', fontsize=12)
        ax1.legend(fontsize=10)
        
        # 右侧图：B的数据
        ax2.plot(df_shifted.index, df_shifted['B'], label='B', color='#1f77b4')
        ax2.set_title('Time Series B', fontsize=16)
        ax2.set_xlabel('Time', fontsize=12)
        ax2.set_ylabel('B', fontsize=12)
        ax2.legend(fontsize=10)
        
        # 添加相关系数注释
        corr = df_shifted['A_shifted'].corr(df_shifted['B'])
        fig.suptitle(f'Correlation: {corr:.2f}', fontsize=14)

    anim = FuncAnimation(fig, animate, frames=101, interval=100, blit=False)
    plt.tight_layout()
    plt.show()

# 创建并显示动画
create_animation()
# Out:
# /Users/mmcao/anaconda3/envs/tinyrag/lib/python3.10/site-packages/matplotlib/animation.py:892: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you output the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import ccf, adfuller, grangercausalitytests
from scipy import stats
import seaborn as sns
from matplotlib.animation import FuncAnimation

# 前面的代码保持不变，直到绘图部分

# 5. 画图展示结果

# 设置Seaborn样式
sns.set_theme(style="darkgrid")

# 交叉相关图和时间序列图保持不变

# 修改后的动态可视化函数
def create_animation():
    fig, ax = plt.subplots(figsize=(12, 6))
    color_A = '#1f77b4'
    color_B = '#d62728'

    # 找到最大相关性对应的lag
    lag_range = 100
    ccf_result = ccf(df['A'], df['B'], adjusted=False)
    lags = np.arange(-lag_range, lag_range + 1)
    ccf_values = ccf_result[len(ccf_result)//2-lag_range:len(ccf_result)//2+lag_range+1]
    max_lag = lags[np.argmax(np.abs(ccf_values))]

    def animate(i):
        ax.clear()
        shift = min(i, abs(max_lag))  # 限制最大shift为max_lag的绝对值
        df_shifted = df.copy()
        if max_lag >= 0:
            df_shifted['A_shifted'] = df_shifted['A'].shift(shift)
        else:
            df_shifted['A_shifted'] = df_shifted['A'].shift(-shift)
        
        # 绘制原始的A和B
        ax.plot(df_shifted.index, df_shifted['A'], label='A', color=color_A)
        ax.plot(df_shifted.index, df_shifted['B'], label='B', color=color_B)
        
        # 绘制shifted的A
        ax.plot(df_shifted.index, df_shifted['A_shifted'], label=f'A (shifted by {shift if max_lag >= 0 else -shift})', 
                color=color_A, linestyle='--', alpha=0.7)
        
        ax.set_title(f'Time Series A and B (A shifted by {shift if max_lag >= 0 else -shift})', fontsize=16)
        ax.set_xlabel('Time', fontsize=12)
        ax.set_ylabel('Value', fontsize=12)
        ax.legend(fontsize=10)
        
        # 添加相关系数注释
        corr = df_shifted['A_shifted'].corr(df_shifted['B'])
        ax.annotate(f'Correlation: {corr:.2f}', xy=(0.05, 0.95), xycoords='axes fraction',
                    bbox=dict(boxstyle="round,pad=0.3", fc="white", ec="gray", alpha=0.8),
                    fontsize=10)

    anim = FuncAnimation(fig, animate, frames=abs(max_lag)+1, interval=100, blit=False)
    plt.tight_layout()
    plt.show()

# 创建并显示动画
create_animation()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import ccf
from matplotlib.animation import FuncAnimation
import seaborn as sns

# 假设df已经定义，包含'A'和'B'列

# 设置Seaborn样式
sns.set_theme(style="darkgrid")

def create_animation():
    fig, ax1 = plt.subplots(figsize=(12, 6))
    ax2 = ax1.twinx()  # 创建第二个y轴
    color_A = '#1f77b4'
    color_B = '#d62728'

    # 找到最大相关性对应的lag
    lag_range = 100
    ccf_result = ccf(df['A'], df['B'], adjusted=False)
    lags = np.arange(-lag_range, lag_range + 1)
    ccf_values = ccf_result[len(ccf_result)//2-lag_range:len(ccf_result)//2+lag_range+1]
    max_lag = lags[np.argmax(np.abs(ccf_values))]

    def animate(i):
        ax1.clear()
        ax2.clear()
        shift = min(i, abs(max_lag))  # 限制最大shift为max_lag的绝对值
        df_shifted = df.copy()
        if max_lag >= 0:
            df_shifted['A_shifted'] = df_shifted['A'].shift(shift)
        else:
            df_shifted['A_shifted'] = df_shifted['A'].shift(-shift)
        
        # 绘制原始的A和shifted的A（在ax1上）
        ax1.plot(df_shifted.index, df_shifted['A'], label='A', color=color_A)
        ax1.plot(df_shifted.index, df_shifted['A_shifted'], 
                 label=f'A (shifted by {shift if max_lag >= 0 else -shift})', 
                 color=color_A, linestyle='--', alpha=0.7)
        
        # 绘制B（在ax2上）
        ax2.plot(df_shifted.index, df_shifted['B'], label='B', color=color_B)
        
        # 设置标题和标签
        ax1.set_title(f'Time Series A and B (A shifted by {shift if max_lag >= 0 else -shift})', fontsize=16)
        ax1.set_xlabel('Time', fontsize=12)
        ax1.set_ylabel('Value of A', fontsize=12, color=color_A)
        ax2.set_ylabel('Value of B', fontsize=12, color=color_B)
        
        # 设置y轴的颜色
        ax1.tick_params(axis='y', labelcolor=color_A)
        ax2.tick_params(axis='y', labelcolor=color_B)
        
        # 添加图例
        lines1, labels1 = ax1.get_legend_handles_labels()
        lines2, labels2 = ax2.get_legend_handles_labels()
        ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left', fontsize=10)
        
        # 添加相关系数注释
        corr = df_shifted['A_shifted'].corr(df_shifted['B'])
        ax1.annotate(f'Correlation: {corr:.2f}', xy=(0.05, 0.95), xycoords='axes fraction',
                     bbox=dict(boxstyle="round,pad=0.3", fc="white", ec="gray", alpha=0.8),
                     fontsize=10)

    anim = FuncAnimation(fig, animate, frames=abs(max_lag)+1, interval=100, blit=False)
    plt.tight_layout()
    plt.show()

# 创建并显示动画
create_animation()
